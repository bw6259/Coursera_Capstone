# %%
# !pip install beautifulsoup4
# !pip install lxml
# !pip install html5lib

# %%
import urllib.request
from urllib.request import urlopen
import bs4
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import requests

# %%
#url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
#html = urllib.request.urlopen(url).read()
#print(html)
#Postcode = []
#Borough = []
#Neighbourhood = []


#soup = BeautifulSoup(html, 'html5lib') #lxml html5lib
#table = soup.find_all('table',class_="wikitable")
#print(table.text)
#rows = table.find_all('tr')
#print(rows)
#tabledata = []
#for row in rows:
 #   for r in row:
  #      if len(r) == 13:
    #        Postcode.append(r)#row.findAll('td'))
   #         print(row.text)
#print(Postcode)
    #Postcode.append(str(row.findAll('td')[0]))
    #Borough.append(str(row.findAll('td')[1]))
    #Neighbourhood.append(str(row.findAll('td')[2]))
#columns = {'Postcode':Postcode, 'Borough':Borough, 'Neighbourhood':Neighbourhood}

#document.querySelector("#mw-content-text > div > table.wikitable.sortable.jquery-tablesorter")

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
html = urllib.request.urlopen(url).read()
#print(html)
Postcode = []
Borough = []
Neighbourhood = []


soup = BeautifulSoup(html, 'html5lib') #lxml html5lib
table = soup.find('table',class_="wikitable") # sortable jquery-tablesorter
#print(table)
test = table.tbody #tr.th.
tdata = test.td
#print(td)
#for rows in test.find_all('td'):
    #for item.text in rows:
        #print(item)
    #print(rows)
#rows = table.find("td").text
#for tr in table.tbody
#print(rows)
#print(test)

# %%
url = 'https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M'
html = urllib.request.urlopen(url).read()
#print(html)
postcode = []
borough = []
neighbourhood = []

soup = BeautifulSoup(html, 'html5lib') #lxml html5lib
table = soup.find('table',class_="wikitable") # sortable jquery-tablesorter
#print(table)
test = table.tbody #tr.th.
a=0
b=1
c=2
for rows in enumerate(test.find_all('td')):
    #print(rows)
    if rows[0] == a:
        a = a+3
        postcode.append(rows[1].text)
    elif rows[0] == b:
        b = b+3
        borough.append(rows[1].text)
    elif rows[0] == c:
        c = c+3
        neighbourhood.append(rows[1].text[:-1])
#print(postcode)    
#print(borough)
#print(neighbourhood)

# %%
wikipage_dict = {'Postcode':postcode, 'Borough':borough, 'Neighbourhood':neighbourhood}
wikipage_df = pd.DataFrame(wikipage_dict)
wikipage_df.set_index('Postcode', inplace=True)
wikipage_df
#print(postcode)    
#print(borough)
#print(neighbourhood)
# Out:
#                    Borough                                      Neighbourhood
# Postcode
# M1A           Not assigned                                       Not assigned
# M2A           Not assigned                                       Not assigned
# M3A             North York                                          Parkwoods
# M4A             North York                                   Victoria Village
# M5A       Downtown Toronto                                       Harbourfront
# M6A             North York                                   Lawrence Heights
# M6A             North York                                     Lawrence Manor
# M7A       Downtown Toronto                                       Queen's Park
# M8A           Not assigned                                       Not assigned
# M9A           Queen's Park                                       Not assigned
# M1B            Scarborough                                              Rouge
# ...

# %%
wikipage_df['Borough'].value_counts()
# Out:
# Not assigned        77
# Etobicoke           44
# North York          38
# Scarborough         37
# Downtown Toronto    37
# Central Toronto     17
# West Toronto        13
# York                 9
# East Toronto         7
# East York            6
# Mississauga          1
# Queen's Park         1
# Name: Borough, dtype: int64

# %%
wiki_notassigned = wikipage_df[wikipage_df.Borough != 'Not assigned']
wiki_notassigned
# Out:
#                    Borough                                      Neighbourhood
# Postcode
# M3A             North York                                          Parkwoods
# M4A             North York                                   Victoria Village
# M5A       Downtown Toronto                                       Harbourfront
# M6A             North York                                   Lawrence Heights
# M6A             North York                                     Lawrence Manor
# M7A       Downtown Toronto                                       Queen's Park
# M9A           Queen's Park                                       Not assigned
# M1B            Scarborough                                              Rouge
# M1B            Scarborough                                            Malvern
# M3B             North York                                    Don Mills North
# M4B              East York                                   Woodbine Gardens
# ...

# %%
wiki_notassigned = wiki_notassigned.reset_index()
#wiki_grouped = wiki_notassigned.groupby(['Postcode','Borough'])
wiki_grouped = wiki_notassigned.groupby('Postcode', as_index=False).agg({'Neighbourhood' : ', '.join, 'Borough' : 'first'})
wiki_grouped
# Out:
#     Postcode                                      Neighbourhood  \
# 0        M1B                                     Rouge, Malvern
# 1        M1C             Highland Creek, Rouge Hill, Port Union
# 2        M1E                  Guildwood, Morningside, West Hill
# 3        M1G                                             Woburn
# 4        M1H                                          Cedarbrae
# 5        M1J                                Scarborough Village
# 6        M1K        East Birchmount Park, Ionview, Kennedy Park
# 7        M1L                    Clairlea, Golden Mile, Oakridge
# 8        M1M    Cliffcrest, Cliffside, Scarborough Village West
# 9        M1N                        Birch Cliff, Cliffside West
# 10       M1P  Dorset Park, Scarborough Town Centre, Wexford ...
# 11       M1R                                  Maryvale, Wexford
# 12       M1S                                          Agincourt
# 13       M1T            Clarks Corners, Sullivan, Tam O'Shanter
# ...

# %%
wiki_grouped = wiki_grouped[['Postcode','Borough','Neighbourhood']]
wiki_grouped
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %%
wiki_clean = wiki_grouped
for item in wiki_clean['Neighbourhood']:
    if item == 'Not assigned':
        item == wiki_clean['Borough']
wiki_clean
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %%
for (wiki_clean['Neighbourhood'].loc[wiki_clean['Neighbourhood'] == 'Not assigned']) in wiki_clean:
    (wiki_clean['Neighbourhood'].loc[wiki_clean['Neighbourhood'] == 'Not assigned']) == (wiki_clean['Borough'].loc[wiki_clean['Neighbourhood'] == 'Not assigned'])
#print(wiki_clean.loc[wiki_clean['Neighbourhood'] == (wiki_clean.loc[wiki_clean['Neighbourhood']])])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print(wiki_clean.loc[wiki_clean['Neighbourhood'] == 'Not assigned'])
# Out:
# Empty DataFrame
# Columns: [Postcode, Borough, Neighbourhood]
# Index: []

# %%
wiki_clean.shape
# Out:
# (103, 3)

# %%
wiki_clean
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %%
#import os
#print(os.getcwd())
df = pd.read_csv('Geospatial_Coordinates.csv')
df.sort_values('Postal Code', ascending=True)
df
# Out:
#     Postal Code   Latitude  Longitude
# 0           M1B  43.806686 -79.194353
# 1           M1C  43.784535 -79.160497
# 2           M1E  43.763573 -79.188711
# 3           M1G  43.770992 -79.216917
# 4           M1H  43.773136 -79.239476
# 5           M1J  43.744734 -79.239476
# 6           M1K  43.727929 -79.262029
# 7           M1L  43.711112 -79.284577
# 8           M1M  43.716316 -79.239476
# 9           M1N  43.692657 -79.264848
# 10          M1P  43.757410 -79.273304
# 11          M1R  43.750072 -79.295849
# 12          M1S  43.794200 -79.262029
# 13          M1T  43.781638 -79.304302
# 14          M1V  43.815252 -79.284577
# 15          M1W  43.799525 -79.318389
# 16          M1X  43.836125 -79.205636
# 17          M2H  43.803762 -79.363452
# 18          M2J  43.778517 -79.346556
# 19          M2K  43.786947 -79.385975
# 20          M2L  43.757490 -79.374714
# 21          M2M  43.789053 -79.408493
# 22          M2N  43.770120 -79.408493
# 23          M2P  43.752758 -79.400049
# ...

# %%
wiki_clean.sort_values('Postcode', ascending=True)
wiki_clean
# Out:
#     Postcode           Borough  \
# 0        M1B       Scarborough
# 1        M1C       Scarborough
# 2        M1E       Scarborough
# 3        M1G       Scarborough
# 4        M1H       Scarborough
# 5        M1J       Scarborough
# 6        M1K       Scarborough
# 7        M1L       Scarborough
# 8        M1M       Scarborough
# 9        M1N       Scarborough
# 10       M1P       Scarborough
# 11       M1R       Scarborough
# 12       M1S       Scarborough
# 13       M1T       Scarborough
# 14       M1V       Scarborough
# 15       M1W       Scarborough
# 16       M1X       Scarborough
# 17       M2H        North York
# 18       M2J        North York
# 19       M2K        North York
# 20       M2L        North York
# 21       M2M        North York
# 22       M2N        North York
# 23       M2P        North York
# 24       M2R        North York
# 25       M3A        North York
# 26       M3B        North York
# 27       M3C        North York
# 28       M3H        North York
# ...

# %%
Postcode = wiki_clean['Postcode']
Borough = wiki_clean['Borough']
Neighbourhood = wiki_clean['Neighbourhood']

# %%
Latitude = []
Longitude = []
for _ in df['Latitude']:
    Latitude.append(_)
for _ in df['Longitude']:
    Longitude.append(_)

# %%
wiki_join_dict = {'Postcode':Postcode, 'Borough':Borough, 'Neighbourhood':Neighbourhood, 'Latitude':Latitude,'Longitude':Longitude}
wiki_join = pd.DataFrame(wiki_join_dict)
wiki_join.head()
# Out:
#   Postcode      Borough                           Neighbourhood   Latitude  \
# 0      M1B  Scarborough                          Rouge, Malvern  43.806686
# 1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union  43.784535
# 2      M1E  Scarborough       Guildwood, Morningside, West Hill  43.763573
# 3      M1G  Scarborough                                  Woburn  43.770992
# 4      M1H  Scarborough                               Cedarbrae  43.773136
#
#    Longitude
# 0 -79.194353
# 1 -79.160497
# 2 -79.188711
# 3 -79.216917
# 4 -79.239476

# %%
#df.to_csv('Geospatial_Coordinates_&_Neighbourhoods.csv')

# %%
import numpy as np  # useful for many scientific computing in Python
import pandas as pd

# %%
# !conda install -c conda-forge folium=0.5.0 --yes
import folium

print('Folium installed and imported!')
# Out:
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\ProgramData\Anaconda3
#
#   added / updated specs:
#     - folium=0.5.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     certifi-2019.11.28         |           py37_0         148 KB  conda-forge
#     conda-4.8.2                |           py37_0         3.0 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         3.2 MB
#
# The following packages will be UPDATED:
#
#   ca-certificates    anaconda::ca-certificates-2019.11.27-0 --> conda-forge::ca-certificates-2019.11.28-hecc5488_0
#   conda                        anaconda::conda-4.8.1-py37_0 --> conda-forge::conda-4.8.2-py37_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
# ...

# %%
Latitude_map = 43.722862
Longitude_map = -79.365741

#df = pd.read_csv('Geospatial_Coordinates_&_Neighbourhoods.csv')
world_map = folium.Map(location=[Latitude_map, Longitude_map], tiles='Stamen Terrain', zoom_start=10)
df_toronto = pd.read_csv('Geospatial_Coordinates_&_Neighbourhoods.csv')
df_toronto.head()
#world_map
# Out:
#    Unnamed: 0 Postcode      Borough                           Neighbourhood  \
# 0           0      M1B  Scarborough                          Rouge, Malvern
# 1           1      M1C  Scarborough  Highland Creek, Rouge Hill, Port Union
# 2           2      M1E  Scarborough       Guildwood, Morningside, West Hill
# 3           3      M1G  Scarborough                                  Woburn
# 4           4      M1H  Scarborough                               Cedarbrae
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
from folium import plugins
world_map = folium.Map(location=[Latitude_map, Longitude_map], zoom_start=10)
neighb = plugins.MarkerCluster().add_to(world_map)

for lat, lng, label in zip(df_toronto.Latitude, df_toronto.Longitude, df_toronto.Neighbourhood):
    neighb.add_child(folium.features.CircleMarker([lat, lng],radius=5, color='yellow',fill=True,fill_color='blue',fill_opacity=0.6))
for lat, lng, label in zip(df_toronto.Latitude, df_toronto.Longitude, df_toronto.Neighbourhood):
    folium.Marker([lat, lng], popup=label).add_to(world_map)    

world_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
